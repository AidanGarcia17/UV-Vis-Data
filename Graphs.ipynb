# %% [markdown]
# <a href="https://colab.research.google.com/github/AidanGarcia17/UV-Vis-Data/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Sample #1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
fn1= '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BaB1.txt.TXT'

wl1, abs1 = np.genfromtxt(fn1, skip_header= 86, unpack= True)

abs_norm = abs/np.max(abs)

plt.plot(wl1, abs1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-f96306562a4a> in <cell line: 5>()
#       3 wl1, abs1 = np.genfromtxt(fn1, skip_header= 86, unpack= True)
#       4
# ----> 5 abs_norm = abs/np.max(abs)
#       6
#       7 plt.plot(wl1, abs1)
#
# TypeError: unsupported operand type(s) for /: 'builtin_function_or_method' and 'builtin_function_or_method'

# %% [markdown]
# # Sample 2

# %%
fn2 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PbBaB2.txt.TXT'

wl2, abs2 = np.genfromtxt(fn2, skip_header = 86, unpack= True)

plt.plot(wl2, abs2)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 3

# %%
fn3 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PbBisB3.txt.TXT'

wl3, abs3 = np.genfromtxt(fn3, skip_header = 86, unpack= True)

plt.plot(wl3, abs3)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 4

# %%
fn4 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PbBisB4.txt.TXT'

wl4, abs4 = np.genfromtxt(fn4, skip_header = 86, unpack= True)

plt.plot(wl4, abs4)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 5

# %%
fn5 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BAB5.TXT'

wl5 , abs5 = np.genfromtxt(fn5, skip_header = 86, unpack=True)

plt.plot(wl5, abs5)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 6

# %%
fn6 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BAB6.TXT'

wl6, abs6 = np.genfromtxt(fn6, skip_header = 86, unpack= True)

plt.plot(wl6, abs6)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 7

# %%
fn7 ='/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BAB7.TXT'

wl7, abs7 = np.genfromtxt(fn7, skip_header = 86, unpack= True)

plt.plot(wl7,abs7)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 8

# %%
fn8 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB8.TXT'

wl8, abs8 = np.genfromtxt(fn8, skip_header = 86, unpack= True)

plt.plot(wl8, abs8)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 9

# %%
fn9= '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB9.TXT'

wl9, abs9 = np.genfromtxt(fn9, skip_header = 86, unpack= True)

plt.plot(wl9, abs9)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 10

# %%
fn10 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB10.TXT'

wl10, abs10 = np.genfromtxt(fn10, skip_header = 86, unpack= True)

plt.plot(wl10, abs10)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 11

# %%
fn11= "/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBISB11.TXT"

wl11, abs11 = np.genfromtxt(fn11, skip_header= 86, unpack= True)

plt.plot(wl11, abs11)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 12
#
# Not sure whats going on here

# %%
fn12 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB12.TXT'

#wl12, abs12 = np.genfromtxt(fn12, skip_header = 86, unpack= True)
wl12, abs12 =  np.genfromtxt(fn12, skip_header = 86, unpack = True)

plt.plot(wl12, abs12)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-18897441c268> in <cell line: 4>()
#       2
#       3 #wl12, abs12 = np.genfromtxt(fn12, skip_header = 86, unpack= True)
# ----> 4 wl12, abs12 =  np.genfromtxt(fn12, skip_header = 86, unpack = True)
#       5
#       6 plt.plot(wl12, abs12)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2001         try:
#    2002             for i in range(skip_header):
# -> 2003                 next(fhd)
#    2004
#    2005             # Keep on until we find the first valid values
#
# ...

# %% [markdown]
# #Sample 13

# %%
fn13 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB13.TXT'

wl13, abs13 = np.genfromtxt(fn13, skip_header = 86, unpack = True)

plt.plot(wl13, abs13)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 14

# %%
fn14 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB14.TXT'

wl14, abs14 = np.genfromtxt(fn14, skip_header = 86, unpack= True)

plt.plot(wl14, abs14)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# #Sample 15

# %%
fn15 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB15.TXT'

wl15, abs15 = np.genfromtxt(fn15, skip_header= 86, unpack= True)

plt.plot(wl15, abs15)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 16

# %%
fn16 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB16.TXT'

wl16, abs16 = np.genfromtxt(fn16, skip_header = 86, unpack= True)

plt.plot(wl16, abs16)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 17

# %%
##fn17 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/'

# %% [markdown]
# # Sample 18

# %%
fn18 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB18.TXT'

wl18, abs18 = np.genfromtxt(fn18, skip_header = 86, unpack= True)

plt.plot(wl18, abs18)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 19

# %%
fn19 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB19.TXT'

wl19, abs19 = np.genfromtxt(fn19, skip_header=86, unpack=True)

plt.plot(wl19, abs19)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 20

# %%
fn20 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB20.TXT'

wl20, abs20 = np.genfromtxt(fn20, skip_header = 86, unpack= True)

plt.plot(wl20, abs20)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 21

# %%
fn21 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB21.TXT'

wl21, abs21 = np.genfromtxt(fn21, skip_header = 86, unpack= True)

plt.plot(wl21, abs21)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 22

# %%
fn22 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB22.TXT'

wl22, abs22 = np.genfromtxt(fn22, skip_header = 86, unpack= True)

plt.plot(wl22, abs22)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 23

# %%
fn23 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB23.TXT'

wl23, abs23 = np.genfromtxt(fn23, skip_header = 86, unpack= True)

plt.plot(wl23, abs23)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 24

# %%
fn24 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB24.TXT'

wl24, abs24 = np.genfromtxt(fn24, skip_header = 86, unpack= True)

plt.plot(wl24, abs24)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 25

# %%
fn25 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB25.TXT'

wl25, abs25 = np.genfromtxt(fn25, skip_header = 86, unpack= True)

plt.plot(wl25, abs25)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 26

# %%
fn26 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB26.TXT'

wl26, abs26 = np.genfromtxt(fn26, skip_header = 86, unpack= True)

plt.plot(wl26, abs26)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 27

# %%
fn27 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB27.TXT'

wl27, abs27 = np.genfromtxt(fn27, skip_header = 86, unpack= True)

plt.plot(wl27, abs27)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 28

# %%
fn28 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBAB28.TXT'

wl28, abs28 = np.genfromtxt(fn28, skip_header = 86, unpack= True)

plt.plot(wl28, abs28)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 29

# %%
fn29 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB29.TXT'

wl29, abs29 = np.genfromtxt(fn29, skip_header = 86, unpack= True)

plt.plot(wl29, abs29)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 30

# %%
fn30 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB30.TXT'

wl30, abs30 = np.genfromtxt(fn30, skip_header = 86, unpack= True)

plt.plot(wl30, abs30)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 31

# %%
fn31 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB31.TXT'

wl31, abs31 = np.genfromtxt(fn31, skip_header = 86, unpack= True)

plt.plot(wl31, abs31)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 32

# %%
fn32 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB32.TXT'

wl32, abs32 = np.genfromtxt(fn32, skip_header = 86, unpack= True)

plt.plot(wl32, abs32)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 33

# %%
fn33 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB33.TXT'

wl33, abs33 = np.genfromtxt(fn33, skip_header = 86, unpack= True)

plt.plot(wl33, abs33)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 34

# %%
fn34 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB34.TXT'

wl34, abs34 = np.genfromtxt(fn34, skip_header = 86, unpack= True)

plt.plot(wl34, abs34)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 35

# %%
fn35 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BAB35.TXT'

wl35, abs35 = np.genfromtxt(fn35, skip_header = 86, unpack= True)

plt.plot(wl35, abs35)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 36

# %%
fn36 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBB36.TXT'

wl36, abs36 = np.genfromtxt(fn36, skip_header = 86, unpack= True)

plt.plot(wl36, abs36)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 37

# %%
fn37 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BAB37.TXT'

wl37, abs37 = np.genfromtxt(fn37, skip_header = 86, unpack= True)

plt.plot(wl37, abs37)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 38

# %%
fn38 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BAB38.TXT'

wl38, abs38 = np.genfromtxt(fn38, skip_header = 86, unpack= True)

plt.plot(wl38, abs38)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 39

# %%
fn39 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/BAB39.TXT'

wl39, abs39 = np.genfromtxt(fn39, skip_header = 86, unpack= True)

plt.plot(wl39, abs39)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 40

# %%
fn40 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBISB40.TXT'

wl40, abs40 = np.genfromtxt(fn40, skip_header = 86, unpack= True)

plt.plot(wl40, abs40)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 41

# %%
fn41 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBIS41.TXT'

wl41, abs41 = np.genfromtxt(fn41, skip_header = 86, unpack= True)

plt.plot(wl41, abs41)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 42

# %%
fn42 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBISB42.TXT'

wl42, abs42 = np.genfromtxt(fn42, skip_header = 86, unpack= True)

plt.plot(wl42, abs42)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 43

# %%
fn43 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBISB43.TXT'

wl43, abs43 = np.genfromtxt(fn43, skip_header = 86, unpack= True)

plt.plot(wl43, abs43)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 44

# %%
fn44 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBISB44.TXT'

wl44, abs44 = np.genfromtxt(fn44, skip_header = 86, unpack= True)

plt.plot(wl44, abs44)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')

# %% [markdown]
# # Sample 45

# %%
fn45 = '/content/drive/Shareddrives/su24-research/Glass_UV_Vis_Data/PBBISB45.TXT'

wl45, abs45 = np.genfromtxt(fn45, skip_header = 86, unpack= True)

plt.plot(wl45, abs45)
plt.xlabel("Wavelength in nm")
plt.ylabel("Absorbance")
# Out:
# Text(0, 0.5, 'Absorbance')
